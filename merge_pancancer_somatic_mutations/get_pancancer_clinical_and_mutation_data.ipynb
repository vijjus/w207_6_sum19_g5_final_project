# %%
import pandas as pd
import urllib.request
import numpy as np
from IPython.display import display

# %%
# This downloads a 753 MB mutations gzip file.  This will take about 1-5 mins depending on your
# connection speed.
print('Downloading mutation data. 753 MB ...')
url = 'http://api.gdc.cancer.gov/data/1c8cfe5f-e52d-41ba-94da-f15ea1337efc'  
urllib.request.urlretrieve(url, './pancancer_mutations.maf.gz')  
print("done.")
# Out:
# Downloading mutation data. 753 MB ...
# done.

# %%
# This downloads an 18 MB clinical data file
print('Downloading clinical data ...')
url = 'http://api.gdc.cancer.gov/data/0fc78496-818b-4896-bd83-52db1f533c5c'  
urllib.request.urlretrieve(url, './pancancer_clinical.txt')  
print("done.")
# Out:
# Downloading clinical data ...
# done.

# %%
# Load the mutations dataframe
print('Loading mutations dataframe ...')
mutations = pd.read_csv("pancancer_mutations.maf.gz", compression='gzip',
                        sep='\t', 
                        usecols=['Tumor_Sample_Barcode','Hugo_Symbol', 
                                 'Variant_Classification', 'Variant_Type'])
print("done.")
print("Mutations count", mutations.Tumor_Sample_Barcode.count())
display(mutations.head())
# Out:
# Loading mutations dataframe ...
# done.
# Mutations count 3600963
#   Hugo_Symbol Variant_Classification Variant_Type  \
# 0       TACC2      Missense_Mutation          SNP
# 1     JAKMIP3                 Silent          SNP
# 2       PANX3      Missense_Mutation          SNP
# 3        SPI1      Missense_Mutation          SNP
# 4     NAALAD2      Missense_Mutation          SNP
#
#            Tumor_Sample_Barcode
# 0  TCGA-02-0003-01A-01D-1490-08
# 1  TCGA-02-0003-01A-01D-1490-08
# 2  TCGA-02-0003-01A-01D-1490-08
# 3  TCGA-02-0003-01A-01D-1490-08
# 4  TCGA-02-0003-01A-01D-1490-08

# %%
# Set mutations index
mutations['row'] = np.arange(len(mutations))
mutations.set_index('row')
# Out:
#         Hugo_Symbol Variant_Classification Variant_Type  \
# row
# 0             TACC2      Missense_Mutation          SNP
# 1           JAKMIP3                 Silent          SNP
# 2             PANX3      Missense_Mutation          SNP
# 3              SPI1      Missense_Mutation          SNP
# 4           NAALAD2      Missense_Mutation          SNP
# 5              FAT3                 Silent          SNP
# 6           MTERFD3      Missense_Mutation          SNP
# 7            BTBD11      Missense_Mutation          SNP
# 8              NOS1                5'Flank          SNP
# 9           SLC2A14      Missense_Mutation          SNP
# 10           SLC2A3      Missense_Mutation          SNP
# 11             EML1      Missense_Mutation          SNP
# 12             MYH6                 Silent          SNP
# 13            AKAP6      Missense_Mutation          SNP
# 14            WDR72                 Silent          SNP
# 15            GNPTG                 Silent          SNP
# 16         MAPK8IP3      Missense_Mutation          SNP
# 17          SPATA22      Missense_Mutation          SNP
# 18            HOXB1      Missense_Mutation          SNP
# 19             TP53      Missense_Mutation          SNP
# 20             TP53      Missense_Mutation          SNP
# 21             ILF3                 Silent          SNP
# 22           PODNL1      Missense_Mutation          SNP
# 23            NLRP5      Missense_Mutation          SNP
# 24           ZNF583      Missense_Mutation          SNP
# 25            PEX14                  3'UTR          SNP
# 26             TPM3      Missense_Mutation          SNP
# 27            NR1I3                 Silent          SNP
# 28             TGM6                  3'UTR          SNP
# 29            TSHZ2      Missense_Mutation          SNP
# ...             ...                    ...          ...
# 3600933        LCP2      Missense_Mutation          SNP
# 3600934    ADAMTS16      Missense_Mutation          SNP
# 3600935      IL31RA                 Silent          SNP
# 3600936      MICAL1      Missense_Mutation          SNP
# 3600937      TRMT11      Missense_Mutation          SNP
# 3600938       HLA-B        Frame_Shift_Ins          INS
# 3600939     C7orf50      Missense_Mutation          SNP
# 3600940         AGK                 Silent          SNP
# 3600941      ZNF777      Missense_Mutation          SNP
# 3600942      PRKAG2                  3'UTR          SNP
# 3600943        DPP6                  5'UTR          SNP
# 3600944        AGMO      Missense_Mutation          SNP
# 3600945       MEOX2      Missense_Mutation          SNP
# 3600946      KBTBD2                 Silent          SNP
# 3600947       CSMD3                 Intron          SNP
# 3600948       TEX15      Missense_Mutation          SNP
# 3600949       FUT10                 Silent          SNP
# 3600950      PCMTD1                  3'UTR          SNP
# 3600951       NELFB      Missense_Mutation          SNP
# 3600952      TOPORS      Missense_Mutation          SNP
# 3600953        SMC5      Missense_Mutation          SNP
# 3600954        SMC5      Missense_Mutation          SNP
# 3600955       TRPM3      Nonsense_Mutation          SNP
# 3600956     SLC6A14                  3'UTR          SNP
# 3600957      ATP1B4                 Silent          SNP
# 3600958       THOC2      Missense_Mutation          SNP
# 3600959    SLC25A14                 Intron          SNP
# 3600960       FGF13                3'Flank          SNP
# 3600961        XIST                    RNA          SNP
# 3600962       SRPX2      Missense_Mutation          SNP
#
#                  Tumor_Sample_Barcode
# row
# 0        TCGA-02-0003-01A-01D-1490-08
# 1        TCGA-02-0003-01A-01D-1490-08
# 2        TCGA-02-0003-01A-01D-1490-08
# 3        TCGA-02-0003-01A-01D-1490-08
# 4        TCGA-02-0003-01A-01D-1490-08
# 5        TCGA-02-0003-01A-01D-1490-08
# 6        TCGA-02-0003-01A-01D-1490-08
# 7        TCGA-02-0003-01A-01D-1490-08
# 8        TCGA-02-0003-01A-01D-1490-08
# 9        TCGA-02-0003-01A-01D-1490-08
# 10       TCGA-02-0003-01A-01D-1490-08
# 11       TCGA-02-0003-01A-01D-1490-08
# 12       TCGA-02-0003-01A-01D-1490-08
# 13       TCGA-02-0003-01A-01D-1490-08
# 14       TCGA-02-0003-01A-01D-1490-08
# 15       TCGA-02-0003-01A-01D-1490-08
# 16       TCGA-02-0003-01A-01D-1490-08
# 17       TCGA-02-0003-01A-01D-1490-08
# 18       TCGA-02-0003-01A-01D-1490-08
# 19       TCGA-02-0003-01A-01D-1490-08
# 20       TCGA-02-0003-01A-01D-1490-08
# 21       TCGA-02-0003-01A-01D-1490-08
# 22       TCGA-02-0003-01A-01D-1490-08
# 23       TCGA-02-0003-01A-01D-1490-08
# 24       TCGA-02-0003-01A-01D-1490-08
# 25       TCGA-02-0003-01A-01D-1490-08
# 26       TCGA-02-0003-01A-01D-1490-08
# 27       TCGA-02-0003-01A-01D-1490-08
# 28       TCGA-02-0003-01A-01D-1490-08
# 29       TCGA-02-0003-01A-01D-1490-08
# ...                               ...
# 3600933  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600934  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600935  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600936  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600937  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600938  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600939  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600940  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600941  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600942  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600943  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600944  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600945  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600946  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600947  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600948  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600949  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600950  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600951  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600952  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600953  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600954  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600955  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600956  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600957  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600958  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600959  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600960  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600961  TCGA-ZX-AA5X-01A-11D-A42O-09
# 3600962  TCGA-ZX-AA5X-01A-11D-A42O-09
#
# [3600963 rows x 4 columns]

# %%
# Load the clinical data
print('Loading clinical dataframe ...')
clinical = pd.read_csv("pancancer_clinical.txt", sep='\t', 
                        usecols=['bcr_patient_uuid','bcr_patient_barcode', 'gender', 
                                 'vital_status', 'days_to_birth', 'days_to_death', 
                                 'age_at_initial_pathologic_diagnosis', 'pathologic_stage', 
                                 'height', 'weight'])

print('Clinical count', clinical.bcr_patient_uuid.count())
display(clinical.head())
# Out:
# Loading clinical dataframe ...
# Clinical count 10956
# /Users/tonyd/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (9,55,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                        bcr_patient_uuid bcr_patient_barcode  gender  \
# 0  B3164F7B-C826-4E08-9EE6-8FF96D29B913        TCGA-OR-A5J1    MALE
# 1  8E7C2E31-D085-4B75-A970-162526DD07A0        TCGA-OR-A5J2  FEMALE
# 2  DFD687BC-6E69-42F7-AF94-D17FC150D1A1        TCGA-OR-A5J3  FEMALE
# 3  5F3E2974-F1DF-47A2-8A8A-29BB525EEEF6        TCGA-OR-A5J4  FEMALE
# 4  802DBD0D-EF07-4C91-AB8D-1DD39532E947        TCGA-OR-A5J5    MALE
#
#   vital_status days_to_birth     days_to_death  \
# 0         Dead        -21496            1355.0
# 1         Dead        -16090              1677
# 2        Alive         -8624  [Not Applicable]
# 3         Dead         -8451               423
# 4         Dead        -11171               365
#
#   age_at_initial_pathologic_diagnosis pathologic_stage height weight
# 0                                  58         Stage II    NaN    NaN
# 1                                  44         Stage IV    NaN    NaN
# 2                                  23        Stage III    NaN    NaN
# 3                                  23         Stage IV    NaN    NaN
# 4                                  30        Stage III    NaN    NaN

# %%
# Read the cancertypes.  These are the matching labels for the mutations file
print("Loading labels dataframe ...")
labels = pd.read_csv("labels.txt", sep='\t')
labels.columns = ["cancer_type"]
labels['row'] = np.arange(len(labels))
labels.set_index('row')
print('Labels count', labels.cancer_type.count())
# Out:
# Loading labels dataframe ...
# Labels count 3600963

# %%
# Merge the labels with the mutations
mutations = mutations.merge(labels, left_on='row', right_on='row')
display(mutations.head())
# Out:
#   Hugo_Symbol Variant_Classification Variant_Type  \
# 0       TACC2      Missense_Mutation          SNP
# 1     JAKMIP3                 Silent          SNP
# 2       PANX3      Missense_Mutation          SNP
# 3        SPI1      Missense_Mutation          SNP
# 4     NAALAD2      Missense_Mutation          SNP
#
#            Tumor_Sample_Barcode  row cancer_type
# 0  TCGA-02-0003-01A-01D-1490-08    0         GBM
# 1  TCGA-02-0003-01A-01D-1490-08    1         GBM
# 2  TCGA-02-0003-01A-01D-1490-08    2         GBM
# 3  TCGA-02-0003-01A-01D-1490-08    3         GBM
# 4  TCGA-02-0003-01A-01D-1490-08    4         GBM

# %%
# Get the patient barcode.  This is what we will use to join the mutations to the clinical data
def parsePatientBarcode(tumor_sample_barcode):
        return tumor_sample_barcode[0:12]

mutations['bcr_patient_barcode'] = mutations['Tumor_Sample_Barcode'].apply(parsePatientBarcode)

# %%
merged = mutations.merge(clinical, left_on='bcr_patient_barcode', right_on='bcr_patient_barcode')
display(merged.head())
merged.Tumor_Sample_Barcode.count()
print('Merged mutations count', merged.Tumor_Sample_Barcode.count())
# Out:
#   Hugo_Symbol Variant_Classification Variant_Type  \
# 0       TACC2      Missense_Mutation          SNP
# 1     JAKMIP3                 Silent          SNP
# 2       PANX3      Missense_Mutation          SNP
# 3        SPI1      Missense_Mutation          SNP
# 4     NAALAD2      Missense_Mutation          SNP
#
#            Tumor_Sample_Barcode  row cancer_type bcr_patient_barcode  \
# 0  TCGA-02-0003-01A-01D-1490-08    0         GBM        TCGA-02-0003
# 1  TCGA-02-0003-01A-01D-1490-08    1         GBM        TCGA-02-0003
# 2  TCGA-02-0003-01A-01D-1490-08    2         GBM        TCGA-02-0003
# 3  TCGA-02-0003-01A-01D-1490-08    3         GBM        TCGA-02-0003
# 4  TCGA-02-0003-01A-01D-1490-08    4         GBM        TCGA-02-0003
#
#                        bcr_patient_uuid gender vital_status days_to_birth  \
# 0  df3c1d61-79c1-43e9-971a-8029497ffeab   MALE         Dead        -18341
# 1  df3c1d61-79c1-43e9-971a-8029497ffeab   MALE         Dead        -18341
# 2  df3c1d61-79c1-43e9-971a-8029497ffeab   MALE         Dead        -18341
# 3  df3c1d61-79c1-43e9-971a-8029497ffeab   MALE         Dead        -18341
# 4  df3c1d61-79c1-43e9-971a-8029497ffeab   MALE         Dead        -18341
#
#   days_to_death age_at_initial_pathologic_diagnosis pathologic_stage height  \
# 0         144.0                                  50              NaN    NaN
# 1         144.0                                  50              NaN    NaN
# 2         144.0                                  50              NaN    NaN
# 3         144.0                                  50              NaN    NaN
# 4         144.0                                  50              NaN    NaN
#
#   weight
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Merged mutations count 3570876

# %%
# Write out new merged dataframe as csv file
print("Writing new csv file with merged mutations, clinical, and cancer types ...")
merged.to_csv("pancancer_mutations_merged.csv")
print("done.")
# Out:
# Writing new csv file with merged mutations, clinical, and cancer types ...
# done.
